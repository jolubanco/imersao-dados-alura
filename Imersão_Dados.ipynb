# %%
import pandas as pd

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true' 
dados = pd.read_csv(url_dados, compression = 'zip') #parametro para descompactar a base de dados
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
#Desafio 07
#removendo o caracter '-' por '_' para facilitar a manipulação
colunas = dados.columns
colunas = colunas.map(lambda x: x.replace('-','_') if isinstance(x,(str)) else x)
dados.columns = colunas
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
mapa = {
    'droga' : 'composto'
}
dados.rename(columns=mapa, inplace = True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['composto'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g_0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True) #normalizando os dados
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True) #normalizando os dados
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
filtro = dados['g_0'] > 0
dados_filtrados = dados[filtro]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos') #o @ serve para indicar ao python que é uma variável que ja foi definida anteriormente
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set() #precisa rodar um vez, por causa de bug do colab, para formatar o gráfico de acordo com o seaborn
plt.figure(figsize = (8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos')) #conta quantas incidencias do dado em questao e plota um graficod e barras
#nome ax é padrão
ax.set_title('Top 5 Compostos') 
plt.show() #elimina as informações mostradas antes do plot

# %%
len(dados['g_0'].unique())
# Out:
# 14367

# %%
dados['g_0'].min()
# Out:
# -5.513

# %%
dados['g_0'].max()
# Out:
# 10.0

# %%
dados['g_0'].hist(bins = 100)

# %%
dados['g_19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g_0  ...          c_98          c_99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
 dados[['g_0','g_1']] #fatiamento do dataframe
# Out:
#           g_0     g_1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[:,'g_0':'g_771'].describe()
# Out:
#                 g_0           g_1  ...         g_770         g_771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:,'g_0':'g_771'].describe().T #Transpondo o dataframe
# Out:
#          count      mean       std     min       25%      50%       75%     max
# g_0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g_1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g_2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g_3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g_4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...        ...       ...       ...     ...       ...      ...       ...     ...
# g_767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g_768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g_769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g_770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g_771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# ...

# %%
dados.loc[:,'g_0':'g_771'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'g_0':'g_771'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'g_0':'g_771'].describe().T['max'].hist(bins=50)

# %%
dados.loc[:,'c_0':'c_99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x = 'g_0', data = dados)

# %%
plt.figure(figsize = (10,8))
sns.boxplot(y = 'g_0', x = 'tratamento', data = dados)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize=True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], values = dados['g_0'], aggfunc='mean')
#retorna a média dos valores do gene g_0 sob ação das demais variáveis
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x = 'g_0', y = 'g_3', data = dados)

# %%
dados[['g_0','g_3']]
# Out:
#           g_0     g_3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x = 'g_0', y = 'g_8', data = dados)

# %%
sns.lmplot(x = 'g_0', y = 'g_8', data = dados, line_kws={'color':'red'})

# %%
sns.lmplot(x = 'g_0', y = 'g_8', data = dados, line_kws={'color':'red'}, col = 'tratamento')

# %%
sns.lmplot(x = 'g_0', y = 'g_8', data = dados, line_kws={'color':'red'}, col = 'tratamento', row = 'tempo')

# %%
dados.loc[:,'g_0':'g_771'].corr()
# Out:
#             g_0       g_1       g_2  ...     g_769     g_770     g_771
# g_0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g_1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g_2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g_3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g_4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g_767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g_768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g_769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g_770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g_771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Compute the correlation matrix
corr = dados.loc[:,'g_0':'g_50'].corr()

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c_0':'c_50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# #Aula 4

# %%
dados_resultados = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/imersaodados3/main/dados/dados_resultados.csv')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False) #exclui a coluna dos indicies e soma cada coluna
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis =1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.drop('id', axis =1).sum(axis = 1).max()
# Out:
# 7

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis =1).sum(axis = 1)

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados,dados_resultados[['id','n_moa','ativo_moa']],on = 'id') #mudar para ativo_moa
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c_98    c_99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()#mudar para ativo_moa
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()#mudar para ativo_moa
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g_0', x = 'composto', hue = 'ativo_moa')#mudar para ativo_moa

# %% [markdown]
# #Aula 5

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c_98    c_99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Proporção da classe tratamento
#
# ###Desafio 04: Quantos tipos de drogas foram investigados?
#
# ###Desafio 05: Procurar na documentação o método query (pandas).
#
# ###Desafio 06: Adicionar títulos, legenda e etc aos gráficos.
#
# ###Desafio 07: Renomear as colunas retirando o hífen
#
# ###Desafio 08: Resumo do que você aprendeu com os dados
#
# ##Aula 2
#
# ###Desafio 01: Ordenar o gráfico countplot
#
# ###Desafio 02: Melhorar a visualização do gráfico
#
# ###Desafio 03: Plotar os histogramas com seaborn
#
# ###Desafio 04: Estudar sobre as estatísticas retornadas no .describe()
#
# ###Desafio 05: Refletir sobre a manipulaão do tamanho das visualizações
#
# ###Desafio 06: Fazer outras análises com o boxplot e até com o histograma
#
# ##Aula 03:
#
# ###Desafio 01: Criar tabelas de frequência com o pandas.groupby()
#
# ###Desafio 02: Normalizar os dados pela coluna no crosstab
#
# ###Desafio 03: Explorar outros agregadores
#
# ###Desafio 04: Explorar o método MELT
#
# ###Desafio 05: Calcular e analizar a correlação entre o G e C. Refletir sobre os efeitos biológicos.
#
# ###Desafio 06: Estudar o código que plota a matriz de correlação(heatmap)
#
# ##Aula 04:
#
# ###Desafio 01: Encontrar o top 10 das ações do MOA(inibidor,agonista,...)
#
# ###Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle, utilizando 0 ou 1, ou ainda true or false
#
# ###Desafio 03: Criar tres colunas para indicar o tempo 24, 48 ou 72. Com 0 e 1
#
# ###Desafio 04: Estudar sobre combinaçoes de DF
#
# ###Desafio 05: Fazer uma análise mais detalhada do boxplot, considerando dose e tempo, para comparar as distribuições
#
# ###Desafio 06: Descobrir se temos algum composto que dependendo da aconfiguração do experimento, ativa algum MOA
#
# ###Desafio 06: Descobrir se temos algum composto que dependendo da aconfiguração do experimento ativa MOA'S diferentes

# %%
#Desafio 02
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
#Desafio 03
com_droga = dados['tratamento'].value_counts()[0]
com_controle = dados['tratamento'].value_counts()[1]
porcentagem = (com_controle*100)/com_droga
print(f'O tratamento com_drogas representa {100 -porcentagem.round(2)} % enquanto com_controle representa {porcentagem.round(2)} %')
# Out:
# O tratamento com_drogas representa 91.5 % enquanto com_controle representa 8.5 %

# %%
#Desafio 04
tipos_de_drogas = dados['composto'].value_counts()
print(f'Foram investigadas {tipos_de_drogas.shape[0]} tipos de drogas.')
# Out:
# Foram investigadas 3289 tipos de drogas.

# %%
#Desafio 05
dados.query('g_0 > 0').head()
# Out:
#              id tratamento  tempo dose  ...    c_96    c_97    c_98    c_99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]
